# %%
import pandas as pd
import censusdata
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.precision', 2)

# %%
# Check the ACS lookup table here:
# https://www.census.gov/programs-surveys/acs/technical-documentation/summary-file-documentation.2015.html
# Targeting data: income, population, age, gender, and race
# Relevant tables: B00001, B00002, B01001, B01002, B02001, B06011
# censusdata.search('acs5', 2015, 'label', 'Block Group')
# censusdata.search('acs5', 2015, 'label', 'Census Tract')
# censusdata.search('acs5', 2015, 'label', 'Block')

# %%
# check vars here.
censusdata.printtable(censusdata.censustable('acs5', 2015, 'B06010'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B06010_001E  | B06010. Place of Birth by Indi | Total:                                                   | int
# B06010_002E  | B06010. Place of Birth by Indi | No income                                                | int
# B06010_003E  | B06010. Place of Birth by Indi | With income:                                             | int
# B06010_004E  | B06010. Place of Birth by Indi | !! With income: $1 to $9,999 or loss                     | int
# B06010_005E  | B06010. Place of Birth by Indi | !! With income: $10,000 to $14,999                       | int
# B06010_006E  | B06010. Place of Birth by Indi | !! With income: $15,000 to $24,999                       | int
# B06010_007E  | B06010. Place of Birth by Indi | !! With income: $25,000 to $34,999                       | int
# B06010_008E  | B06010. Place of Birth by Indi | !! With income: $35,000 to $49,999                       | int
# B06010_009E  | B06010. Place of Birth by Indi | !! With income: $50,000 to $64,999                       | int
# B06010_010E  | B06010. Place of Birth by Indi | !! With income: $65,000 to $74,999                       | int
# B06010_011E  | B06010. Place of Birth by Indi | !! With income: $75,000 or more                          | int
# B06010_012E  | B06010. Place of Birth by Indi | Born in state of residence:                              | int
# B06010_013E  | B06010. Place of Birth by Indi | !! Born in state of residence: No income                 | int
# B06010_014E  | B06010. Place of Birth by Indi | !! Born in state of residence: With income:              | int
# B06010_015E  | B06010. Place of Birth by Indi | !! !! Born in state of residence: With income: $1 to $9, | int
# B06010_016E  | B06010. Place of Birth by Indi | !! !! Born in state of residence: With income: $10,000 t | int
# B06010_017E  | B06010. Place of Birth by Indi | !! !! Born in state of residence: With income: $15,000 t | int
# B06010_018E  | B06010. Place of Birth by Indi | !! !! Born in state of residence: With income: $25,000 t | int
# B06010_019E  | B06010. Place of Birth by Indi | !! !! Born in state of residence: With income: $35,000 t | int
# B06010_020E  | B06010. Place of Birth by Indi | !! !! Born in state of residence: With income: $50,000 t | int
# B06010_021E  | B06010. Place of Birth by Indi | !! !! Born in state of residence: With income: $65,000 t | int
# B06010_022E  | B06010. Place of Birth by Indi | !! !! Born in state of residence: With income: $75,000 o | int
# B06010_023E  | B06010. Place of Birth by Indi | Born in other state in the United States:                | int
# B06010_024E  | B06010. Place of Birth by Indi | !! Born in other state in the United States: No income   | int
# B06010_025E  | B06010. Place of Birth by Indi | !! Born in other state in the United States: With income | int
# B06010_026E  | B06010. Place of Birth by Indi | !! !! Born in other state in the United States: With inc | int
# B06010_027E  | B06010. Place of Birth by Indi | !! !! Born in other state in the United States: With inc | int
# B06010_028E  | B06010. Place of Birth by Indi | !! !! Born in other state in the United States: With inc | int
# B06010_029E  | B06010. Place of Birth by Indi | !! !! Born in other state in the United States: With inc | int
# B06010_030E  | B06010. Place of Birth by Indi | !! !! Born in other state in the United States: With inc | int
# B06010_031E  | B06010. Place of Birth by Indi | !! !! Born in other state in the United States: With inc | int
# B06010_032E  | B06010. Place of Birth by Indi | !! !! Born in other state in the United States: With inc | int
# B06010_033E  | B06010. Place of Birth by Indi | !! !! Born in other state in the United States: With inc | int
# B06010_034E  | B06010. Place of Birth by Indi | Native; born outside the United States:                  | int
# B06010_035E  | B06010. Place of Birth by Indi | !! Native; born outside the United States: No income     | int
# B06010_036E  | B06010. Place of Birth by Indi | !! Native; born outside the United States: With income:  | int
# B06010_037E  | B06010. Place of Birth by Indi | !! !! Native; born outside the United States: With incom | int
# B06010_038E  | B06010. Place of Birth by Indi | !! !! Native; born outside the United States: With incom | int
# B06010_039E  | B06010. Place of Birth by Indi | !! !! Native; born outside the United States: With incom | int
# B06010_040E  | B06010. Place of Birth by Indi | !! !! Native; born outside the United States: With incom | int
# B06010_041E  | B06010. Place of Birth by Indi | !! !! Native; born outside the United States: With incom | int
# B06010_042E  | B06010. Place of Birth by Indi | !! !! Native; born outside the United States: With incom | int
# B06010_043E  | B06010. Place of Birth by Indi | !! !! Native; born outside the United States: With incom | int
# B06010_044E  | B06010. Place of Birth by Indi | !! !! Native; born outside the United States: With incom | int
# B06010_045E  | B06010. Place of Birth by Indi | Foreign born:                                            | int
# B06010_046E  | B06010. Place of Birth by Indi | !! Foreign born: No income                               | int
# B06010_047E  | B06010. Place of Birth by Indi | !! Foreign born: With income:                            | int
# B06010_048E  | B06010. Place of Birth by Indi | !! !! Foreign born: With income: $1 to $9,999 or loss    | int
# B06010_049E  | B06010. Place of Birth by Indi | !! !! Foreign born: With income: $10,000 to $14,999      | int
# B06010_050E  | B06010. Place of Birth by Indi | !! !! Foreign born: With income: $15,000 to $24,999      | int
# B06010_051E  | B06010. Place of Birth by Indi | !! !! Foreign born: With income: $25,000 to $34,999      | int
# B06010_052E  | B06010. Place of Birth by Indi | !! !! Foreign born: With income: $35,000 to $49,999      | int
# B06010_053E  | B06010. Place of Birth by Indi | !! !! Foreign born: With income: $50,000 to $64,999      | int
# B06010_054E  | B06010. Place of Birth by Indi | !! !! Foreign born: With income: $65,000 to $74,999      | int
# B06010_055E  | B06010. Place of Birth by Indi | !! !! Foreign born: With income: $75,000 or more         | int
# -------------------------------------------------------------------------------------------------------------------

# %%
# variable list
var_list = ['B00001_001E', 'B00002_001E', 
            'B01001_001E', 'B01001_002E', 'B01001_026E', 
            'B01002_001E', 
            'B02001_001E', 'B02001_002E', 'B02001_003E', 'B02001_004E', 'B02001_005E', 
            'B06010_001E', 'B06010_002E', 'B06010_003E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E', 'B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E']

var_names = ['total_pop', 'total_houses', 
             'total_sex', 'male', 'female',
             'median_age',
             'total_race', 'white', 'black', 'native', 'asian',
             'total_pop_inc', 'pop_no_inc', 'pop_with_inc', 'pop_inc_10k', 'pop_inc_1k_15k', 'pop_inc_15k_25k', 'pop_inc_25k_35k', 'pop_inc_35k_50k', 'pop_inc_50k_65k', 'pop_inc_65k_75k', 'pop_inc_75k']

# %%
# cook data
cook_tract = censusdata.download('acs5', 2015,
                                 censusdata.censusgeo([('state', '17'), ('county', '031'), ('tract', '*')]),
                                 var_list)

# %%
print(cook_tract.shape)
# Out:
# (1319, 22)

# %%
# replace names
cook_tract.columns = var_names

# clean cook county data
state_fips=['17']*cook_tract.shape[0]
county_fips=['031']*cook_tract.shape[0]
tract_fips=[]
full_tract_fips=[]

for i in range(cook_tract.shape[0]):
    tract_fips.append(cook_tract.index[i].params()[2][1])
    full_tract_fips.append('17'+'031'+cook_tract.index[i].params()[2][1])

cook_tract['state_fips']=state_fips
cook_tract['county_fips']=county_fips
cook_tract['tract_fips']=tract_fips
cook_tract['full_tract_fips']=full_tract_fips

# reset index
cook_tract.reset_index(drop = True, inplace = True)
cook_tract
# Out:
#       total_pop  total_houses  total_sex  male  female  median_age  total_race  white  black  native  ...  pop_inc_1k_15k  pop_inc_15k_25k  pop_inc_25k_35k  pop_inc_35k_50k  pop_inc_50k_65k  pop_inc_65k_75k  pop_inc_75k  state_fips  county_fips  tract_fips
# 0           334           121       7751  3770    3981        45.6        7751    562   6770       3  ...             564              711              544              819              637              194          748          17          031      700501
# 1           245            79       3162  1598    1564        43.4        3162    107   2816       0  ...             211              177              190              241              224              143          485          17          031      700502
# 2           149            75       1290   605     685        28.9        1290     66   1224       0  ...             106              119               52               59               25               26           21          17          031      710100
# 3           286           148       5397  2408    2989        31.5        5397    143   5146       0  ...             425              651              463              232              118               55           52          17          031      710200
# 4           152            77       1301   542     759        39.8        1301      0   1268       4  ...             112              241               97               47               51               10           32          17          031      710300
# ...         ...           ...        ...   ...     ...         ...         ...    ...    ...     ...  ...             ...              ...              ...              ...              ...              ...          ...         ...          ...         ...
# 1314        452           137       6785  3136    3649        32.0        6785   2243    930      40  ...             348              721              794              475              360              150          226          17          031      700200
# 1315        423           133       6151  3184    2967        33.6        6151   3237    678      53  ...             367              746              604              607              374              103          198          17          031      700301
# 1316        409           140       5314  2699    2615        34.8        5314   3270    918       6  ...             336              616              601              339              253              206          429          17          031      700302
# 1317        442           147       6153  3181    2972        32.6        6153   1332   3665      13  ...             488              484              453              585              568              221          424          17          031      700401
# 1318        297            95       4192  1947    2245        35.7        4192    699   2974       0  ...             176              379              328              323              355               78          410          17          031      700402
#
# [1319 rows x 25 columns]

# %%
cook_tract.shape
# Out:
# (1319, 25)

# %%
# state number list
state_df = pd.read_csv('./data_usa/state_fips.csv')
state_dir = {}
for key,item in zip(state_df['Postal Code'], state_df['FIPS']):
    # first, control the digits
    item = str(item)
    if len(str(item)) == 1:
        item = '0'+str(item)
    # 
    if str(item) not in ['60','66','69','72','78','02','15']:
        state_dir[item] = key # ahhh...the order sucks
        
state_dir
# state_dic = []
# Out:
# {'01': 'AL',
#  '04': 'AZ',
#  '05': 'AR',
#  '06': 'CA',
#  '08': 'CO',
#  '09': 'CT',
#  '10': 'DE',
#  '12': 'FL',
#  '13': 'GA',
#  '16': 'ID',
#  '17': 'IL',
#  '18': 'IN',
#  '19': 'IA',
#  '20': 'KS',
#  '21': 'KY',
#  '22': 'LA',
#  '23': 'ME',
#  '24': 'MD',
#  '25': 'MA',
#  '26': 'MI',
#  '27': 'MN',
#  '28': 'MS',
#  '29': 'MO',
#  '30': 'MT',
#  '31': 'NE',
#  '32': 'NV',
#  '33': 'NH',
#  '34': 'NJ',
#  '35': 'NM',
#  '36': 'NY',
#  '37': 'NC',
#  '38': 'ND',
#  '39': 'OH',
#  '40': 'OK',
#  '41': 'OR',
#  '42': 'PA',
#  '44': 'RI',
#  '45': 'SC',
#  '46': 'SD',
#  '47': 'TN',
#  '48': 'TX',
#  '49': 'UT',
#  '50': 'VT',
#  '51': 'VA',
#  '53': 'WA',
#  '54': 'WV',
#  '55': 'WI',
#  '56': 'WY'}

# %%
# us tract data
us_tract = {}

for key in state_dir.keys():
    print(state_dir[key])
    us_tract[key] = censusdata.download('acs5', 2015,
                                 censusdata.censusgeo([('state', key), ('tract', '*')]),
                                 var_list)
# Out:
# AL
# AZ
# AR
# CA
# CO
# CT
# DE
# FL
# GA
# ID
# IL
# IN
# IA
# KS
# KY
# LA
# ME
# MD
# MA
# MI
# MN
# MS
# MO
# MT
# NE
# NV
# NH
# NJ
# NM
# NY
# NC
# ND
# OH
# OK
# OR
# PA
# RI
# SC
# SD
# TN
# TX
# UT
# VT
# VA
# WA
# WV
# WI
# WY

# %%
us_tract_df = pd.concat(us_tract.values())

# %%
# replace names
us_tract_df.columns = var_names

# clean cook county data
state_fips=[]
county_fips=[]
tract_fips=[]
full_tract_fips=[]

for i in range(us_tract_df.shape[0]):
    state_fips.append(us_tract_df.index[i].params()[0][1])
    county_fips.append(us_tract_df.index[i].params()[1][1])
    tract_fips.append(us_tract_df.index[i].params()[2][1])
    full_tract_fips.append(us_tract_df.index[i].params()[0][1]+us_tract_df.index[i].params()[1][1]+us_tract_df.index[i].params()[2][1])

us_tract_df['state_fips']=state_fips
us_tract_df['county_fips']=county_fips
us_tract_df['tract_fips']=tract_fips
us_tract_df['full_tract_fips']=full_tract_fips

# reset index
us_tract_df.reset_index(drop = True, inplace = True)
us_tract_df
# Out:
#        total_pop  total_houses  total_sex  male  female  median_age  total_race  white  black  native  ...  pop_inc_15k_25k  pop_inc_25k_35k  pop_inc_35k_50k  pop_inc_50k_65k  pop_inc_65k_75k  pop_inc_75k  state_fips  county_fips  tract_fips  full_tract_fips
# 0          341.0         126.0       5143  2180    2963        39.0        5143   4036    884      31  ...              690              519              547              400              133          211          01          097      006501      01097006501
# 1          331.0         133.0      11578  5705    5873        37.6       11578  10678    451       0  ...             1115              737             1287              863              277         1181          01          097      006502      01097006502
# 2          266.0         101.0       5574  2788    2786        38.9        5574   5033    419      12  ...              785              520              425              418              138          283          01          097      006600      01097006600
# 3          318.0         128.0       6436  3174    3262        39.8        6436   4799    883      11  ...              993              363              340              504               53          315          01          097      006701      01097006701
# 4          231.0         112.0       3270  1564    1706        39.0        3270   2332    415       0  ...              469              414              357              188                0           92          01          097      006702      01097006702
# ...          ...           ...        ...   ...     ...         ...         ...    ...    ...     ...  ...              ...              ...              ...              ...              ...          ...         ...          ...         ...              ...
# 72354      318.0         189.0       1797   906     891        37.6        1797   1720     17       0  ...              116              184               95              150               51          339          56          037      971600      56037971600
# 72355      354.0         169.0       4830  2335    2495        48.7        4830   4731     27       8  ...              812              382              520              514              310          710          56          039      967600      56039967600
# 72356      193.0          85.0       2396  1201    1195        32.2        2396   2170      7       7  ...              287              408              250              338               79          125          56          039      967701      56039967701
# 72357      245.0         161.0       7099  4041    3058        36.8        7099   6466      0       4  ...              956              572              916              744              176          873          56          039      967702      56039967702
# 72358      333.0         166.0       7986  3960    4026        36.6        7986   7418     38      98  ...              855             1318              715              793              502         1214          56          039      967800      56039967800
#
# [72359 rows x 26 columns]

# %%
us_tract_df.shape
# Out:
# (72359, 26)

# %% [markdown]
# ### Save files

# %%
import pickle

with open('../../data/raw_data/cook_tract.pickle', 'wb') as f:
    pickle.dump(cook_tract, f)

with open('../../data/raw_data/usa_tract.pickle', 'wb') as f:
    pickle.dump(us_tract_df, f)

# %%
# with open('./data_usa/cook_tract.pickle', 'rb') as f:
#     cook_read = pickle.load(f)

# %%
us_tract_df.index[i].params()[0][1]+us_tract_df.index[i].params()[1][1]+cook_tract.index[i].params()[2][1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/range.py in __getitem__(self, key)
#     671             try:
# --> 672                 return self._range[new_key]
#     673             except IndexError:
#
# IndexError: range object index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-86-aeca4f0aba4d> in <module>
# ----> 1 us_tract_df.index[i].params()[0][1]+us_tract_df.index[i].params()[1][1]+cook_tract.index[i].params()[2][1]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/range.py in __getitem__(self, key)
#     674                 raise IndexError(
#     675                     "index {key} is out of bounds for axis 0 "
# --> 676                     "with size {size}".format(key=key, size=len(self))
#     677                 )
#     678         elif is_scalar(key):
#
# IndexError: index 72358 is out of bounds for axis 0 with size 1319

# %%
i=0
us_tract_df.index[i].params()
# Out:
# (('state', '01'), ('county', '097'), ('tract', '006501'))

# %%
censusdata.censusgeo([('state', '17'), ('county', '031'), ('tract', '*')]).sumlevel()
# Out:
# '140'

# %%
cookbg.index[0].params()[2][1]
# Out:
# '700501'

# %%
cookbg = censusdata.geographies(censusdata.censusgeo([('state', '17'), ('county', '031'), ('tract', '*')]), 'acs5', 2015)

# %%
cookbg
# Out:
# {'Census Tract 7102, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '710200'))),
#  'Census Tract 7005.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '700501'))),
#  'Census Tract 7005.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '700502'))),
#  'Census Tract 7101, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '710100'))),
#  'Census Tract 7103, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '710300'))),
#  'Census Tract 7104, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '710400'))),
#  'Census Tract 7105, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '710500'))),
#  'Census Tract 7106, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '710600'))),
#  'Census Tract 7107, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '710700'))),
#  'Census Tract 7108, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '710800'))),
#  'Census Tract 7109, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '710900'))),
#  'Census Tract 7110, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '711000'))),
#  'Census Tract 7111, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '711100'))),
#  'Census Tract 7112, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '711200'))),
#  'Census Tract 7113, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '711300'))),
#  'Census Tract 7114, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '711400'))),
#  'Census Tract 7115, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '711500'))),
#  'Census Tract 7201, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '720100'))),
#  'Census Tract 7202, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '720200'))),
#  'Census Tract 7203, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '720300'))),
#  'Census Tract 7204, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '720400'))),
#  'Census Tract 7205, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '720500'))),
#  'Census Tract 7206, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '720600'))),
#  'Census Tract 7207, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '720700'))),
#  'Census Tract 7301, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '730100'))),
#  'Census Tract 7302.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '730201'))),
#  'Census Tract 7302.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '730202'))),
#  'Census Tract 7303, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '730300'))),
#  'Census Tract 7304, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '730400'))),
#  'Census Tract 7305, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '730500'))),
#  'Census Tract 7306, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '730600'))),
#  'Census Tract 7307, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '730700'))),
#  'Census Tract 7401, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '740100'))),
#  'Census Tract 7402, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '740200'))),
#  'Census Tract 7403, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '740300'))),
#  'Census Tract 7404, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '740400'))),
#  'Census Tract 7501, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '750100'))),
#  'Census Tract 7502, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '750200'))),
#  'Census Tract 7503, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '750300'))),
#  'Census Tract 7504, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '750400'))),
#  'Census Tract 7505, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '750500'))),
#  'Census Tract 7506, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '750600'))),
#  'Census Tract 7608.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '760801'))),
#  'Census Tract 7608.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '760802'))),
#  'Census Tract 7608.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '760803'))),
#  'Census Tract 7702.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '770201'))),
#  'Census Tract 7702.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '770202'))),
#  'Census Tract 7703, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '770300'))),
#  'Census Tract 7705, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '770500'))),
#  'Census Tract 7704, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '770400'))),
#  'Census Tract 7706.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '770601'))),
#  'Census Tract 7706.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '770602'))),
#  'Census Tract 7707, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '770700'))),
#  'Census Tract 7708, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '770800'))),
#  'Census Tract 7709.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '770901'))),
#  'Census Tract 7709.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '770902'))),
#  'Census Tract 8001, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '800100'))),
#  'Census Tract 8002, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '800200'))),
#  'Census Tract 8003, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '800300'))),
#  'Census Tract 8004, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '800400'))),
#  'Census Tract 8005, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '800500'))),
#  'Census Tract 8006, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '800600'))),
#  'Census Tract 8007, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '800700'))),
#  'Census Tract 8008, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '800800'))),
#  'Census Tract 8009, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '800900'))),
#  'Census Tract 8010, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801000'))),
#  'Census Tract 8011, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801100'))),
#  'Census Tract 8012, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801200'))),
#  'Census Tract 8013, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801300'))),
#  'Census Tract 8014, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801400'))),
#  'Census Tract 8015, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801500'))),
#  'Census Tract 8016.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801601'))),
#  'Census Tract 8016.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801603'))),
#  'Census Tract 8016.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801605'))),
#  'Census Tract 8016.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801606'))),
#  'Census Tract 8016.07, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801607'))),
#  'Census Tract 8016.08, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801608'))),
#  'Census Tract 8017.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801701'))),
#  'Census Tract 8017.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801702'))),
#  'Census Tract 8018, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801800'))),
#  'Census Tract 8019.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801901'))),
#  'Census Tract 8019.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '801902'))),
#  'Census Tract 8020.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802002'))),
#  'Census Tract 8020.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802003'))),
#  'Census Tract 8020.04, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802004'))),
#  'Census Tract 8021, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802100'))),
#  'Census Tract 8022, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802200'))),
#  'Census Tract 8023, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802300'))),
#  'Census Tract 8024.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802402'))),
#  'Census Tract 8024.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802403'))),
#  'Census Tract 8024.04, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802404'))),
#  'Census Tract 8025.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802503'))),
#  'Census Tract 8025.04, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802504'))),
#  'Census Tract 8025.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802505'))),
#  'Census Tract 8025.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802506'))),
#  'Census Tract 101, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '010100'))),
#  'Census Tract 102.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '010201'))),
#  'Census Tract 102.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '010202'))),
#  'Census Tract 103, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '010300'))),
#  'Census Tract 104, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '010400'))),
#  'Census Tract 105.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '010501'))),
#  'Census Tract 105.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '010502'))),
#  'Census Tract 105.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '010503'))),
#  'Census Tract 106, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '010600'))),
#  'Census Tract 107.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '010701'))),
#  'Census Tract 107.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '010702'))),
#  'Census Tract 201, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020100'))),
#  'Census Tract 202, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020200'))),
#  'Census Tract 203.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020301'))),
#  'Census Tract 203.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020302'))),
#  'Census Tract 8026.07, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802607'))),
#  'Census Tract 204, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020400'))),
#  'Census Tract 205, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020500'))),
#  'Census Tract 8026.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802605'))),
#  'Census Tract 8026.08, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802608'))),
#  'Census Tract 8026.09, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802609'))),
#  'Census Tract 8026.10, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802610'))),
#  'Census Tract 8027.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802701'))),
#  'Census Tract 8027.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802702'))),
#  'Census Tract 8028.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802801'))),
#  'Census Tract 8028.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802802'))),
#  'Census Tract 8029, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '802900'))),
#  'Census Tract 8030.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803005'))),
#  'Census Tract 8030.07, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803007'))),
#  'Census Tract 8030.08, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803008'))),
#  'Census Tract 8030.10, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803010'))),
#  'Census Tract 8030.12, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803012'))),
#  'Census Tract 8030.13, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803013'))),
#  'Census Tract 8030.14, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803014'))),
#  'Census Tract 8030.15, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803015'))),
#  'Census Tract 8030.16, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803016'))),
#  'Census Tract 8030.17, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803017'))),
#  'Census Tract 8031, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803100'))),
#  'Census Tract 8032, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803200'))),
#  'Census Tract 8033, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803300'))),
#  'Census Tract 8034, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803400'))),
#  'Census Tract 8035, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803500'))),
#  'Census Tract 8036.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803603'))),
#  'Census Tract 8036.04, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803604'))),
#  'Census Tract 8036.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803605'))),
#  'Census Tract 8036.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803606'))),
#  'Census Tract 8036.07, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803607'))),
#  'Census Tract 8036.08, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803608'))),
#  'Census Tract 8036.10, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803610'))),
#  'Census Tract 8036.11, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803611'))),
#  'Census Tract 8036.12, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803612'))),
#  'Census Tract 8037.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803701'))),
#  'Census Tract 8037.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803702'))),
#  'Census Tract 8038, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803800'))),
#  'Census Tract 8039.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803901'))),
#  'Census Tract 8039.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '803902'))),
#  'Census Tract 8040, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804000'))),
#  'Census Tract 8041.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804102'))),
#  'Census Tract 8041.04, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804104'))),
#  'Census Tract 8041.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804105'))),
#  'Census Tract 8041.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804106'))),
#  'Census Tract 8041.08, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804108'))),
#  'Census Tract 8041.09, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804109'))),
#  'Census Tract 206.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020601'))),
#  'Census Tract 206.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020602'))),
#  'Census Tract 207.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020701'))),
#  'Census Tract 207.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020702'))),
#  'Census Tract 208.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020801'))),
#  'Census Tract 208.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020802'))),
#  'Census Tract 209.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020901'))),
#  'Census Tract 209.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '020902'))),
#  'Census Tract 301.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030101'))),
#  'Census Tract 301.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030102'))),
#  'Census Tract 301.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030103'))),
#  'Census Tract 301.04, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030104'))),
#  'Census Tract 302, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030200'))),
#  'Census Tract 303, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030300'))),
#  'Census Tract 304, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030400'))),
#  'Census Tract 305, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030500'))),
#  'Census Tract 306.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030601'))),
#  'Census Tract 306.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030603'))),
#  'Census Tract 306.04, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030604'))),
#  'Census Tract 307.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030701'))),
#  'Census Tract 307.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030702'))),
#  'Census Tract 307.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030703'))),
#  'Census Tract 307.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030706'))),
#  'Census Tract 308, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030800'))),
#  'Census Tract 309, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '030900'))),
#  'Census Tract 310, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '031000'))),
#  'Census Tract 311, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '031100'))),
#  'Census Tract 312, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '031200'))),
#  'Census Tract 313, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '031300'))),
#  'Census Tract 314, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '031400'))),
#  'Census Tract 315.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '031501'))),
#  'Census Tract 315.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '031502'))),
#  'Census Tract 317, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '031700'))),
#  'Census Tract 318, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '031800'))),
#  'Census Tract 319, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '031900'))),
#  'Census Tract 321, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '032100'))),
#  'Census Tract 401, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '040100'))),
#  'Census Tract 402.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '040201'))),
#  'Census Tract 402.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '040202'))),
#  'Census Tract 403, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '040300'))),
#  'Census Tract 404.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '040401'))),
#  'Census Tract 404.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '040402'))),
#  'Census Tract 406, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '040600'))),
#  'Census Tract 407, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '040700'))),
#  'Census Tract 502, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '050200'))),
#  'Census Tract 408, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '040800'))),
#  'Census Tract 409, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '040900'))),
#  'Census Tract 501, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '050100'))),
#  'Census Tract 8042.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804201'))),
#  'Census Tract 8042.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804202'))),
#  'Census Tract 8043.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804305'))),
#  'Census Tract 8043.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804306'))),
#  'Census Tract 8043.08, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804308'))),
#  'Census Tract 8043.09, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804309'))),
#  'Census Tract 8043.10, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804310'))),
#  'Census Tract 8043.11, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804311'))),
#  'Census Tract 8044.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804403'))),
#  'Census Tract 8044.04, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804404'))),
#  'Census Tract 8044.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804405'))),
#  'Census Tract 8044.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804406'))),
#  'Census Tract 8045.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804505'))),
#  'Census Tract 8045.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804506'))),
#  'Census Tract 8045.07, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804507'))),
#  'Census Tract 8045.08, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804508'))),
#  'Census Tract 8045.09, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804509'))),
#  'Census Tract 8045.10, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804510'))),
#  'Census Tract 8045.11, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804511'))),
#  'Census Tract 8046.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804603'))),
#  'Census Tract 8046.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804606'))),
#  'Census Tract 8046.07, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804607'))),
#  'Census Tract 8046.08, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804608'))),
#  'Census Tract 8046.09, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804609'))),
#  'Census Tract 8046.10, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804610'))),
#  'Census Tract 8046.11, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804611'))),
#  'Census Tract 8047.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804701'))),
#  'Census Tract 8047.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804705'))),
#  'Census Tract 8047.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804706'))),
#  'Census Tract 8047.09, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804709'))),
#  'Census Tract 8047.10, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804710'))),
#  'Census Tract 8047.11, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804711'))),
#  'Census Tract 8047.12, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804712'))),
#  'Census Tract 8047.13, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804713'))),
#  'Census Tract 8047.14, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804714'))),
#  'Census Tract 8047.15, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804715'))),
#  'Census Tract 8047.16, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804716'))),
#  'Census Tract 8048.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804803'))),
#  'Census Tract 8048.04, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804804'))),
#  'Census Tract 8048.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804805'))),
#  'Census Tract 8048.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804806'))),
#  'Census Tract 8048.07, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804807'))),
#  'Census Tract 8048.08, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804808'))),
#  'Census Tract 8048.09, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804809'))),
#  'Census Tract 8048.10, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804810'))),
#  'Census Tract 8049.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804901'))),
#  'Census Tract 503, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '050300'))),
#  'Census Tract 505, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '050500'))),
#  'Census Tract 506, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '050600'))),
#  'Census Tract 507, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '050700'))),
#  'Census Tract 508, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '050800'))),
#  'Census Tract 509, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '050900'))),
#  'Census Tract 510, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '051000'))),
#  'Census Tract 511, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '051100'))),
#  'Census Tract 512, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '051200'))),
#  'Census Tract 513, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '051300'))),
#  'Census Tract 514, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '051400'))),
#  'Census Tract 601, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '060100'))),
#  'Census Tract 602, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '060200'))),
#  'Census Tract 603, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '060300'))),
#  'Census Tract 604, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '060400'))),
#  'Census Tract 605, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '060500'))),
#  'Census Tract 608, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '060800'))),
#  'Census Tract 609, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '060900'))),
#  'Census Tract 610, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '061000'))),
#  'Census Tract 611, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '061100'))),
#  'Census Tract 612, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '061200'))),
#  'Census Tract 615, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '061500'))),
#  'Census Tract 618, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '061800'))),
#  'Census Tract 619.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '061901'))),
#  'Census Tract 619.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '061902'))),
#  'Census Tract 620, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '062000'))),
#  'Census Tract 621, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '062100'))),
#  'Census Tract 622, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '062200'))),
#  'Census Tract 623, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '062300'))),
#  'Census Tract 624, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '062400'))),
#  'Census Tract 625, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '062500'))),
#  'Census Tract 626, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '062600'))),
#  'Census Tract 627, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '062700'))),
#  'Census Tract 628, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '062800'))),
#  'Census Tract 629, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '062900'))),
#  'Census Tract 630, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '063000'))),
#  'Census Tract 631, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '063100'))),
#  'Census Tract 632, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '063200'))),
#  'Census Tract 633.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '063301'))),
#  'Census Tract 633.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '063302'))),
#  'Census Tract 633.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '063303'))),
#  'Census Tract 634, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '063400'))),
#  'Census Tract 701.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '070101'))),
#  'Census Tract 701.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '070102'))),
#  'Census Tract 701.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '070103'))),
#  'Census Tract 702, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '070200'))),
#  'Census Tract 703, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '070300'))),
#  'Census Tract 704, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '070400'))),
#  'Census Tract 8049.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '804902'))),
#  'Census Tract 8050.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805001'))),
#  'Census Tract 8050.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805002'))),
#  'Census Tract 8051.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805105'))),
#  'Census Tract 8051.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805106'))),
#  'Census Tract 8051.07, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805107'))),
#  'Census Tract 8051.08, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805108'))),
#  'Census Tract 8051.09, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805109'))),
#  'Census Tract 8051.10, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805110'))),
#  'Census Tract 8051.11, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805111'))),
#  'Census Tract 8051.12, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805112'))),
#  'Census Tract 8052.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805201'))),
#  'Census Tract 8052.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805202'))),
#  'Census Tract 8053.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805301'))),
#  'Census Tract 8053.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805302'))),
#  'Census Tract 8054.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805401'))),
#  'Census Tract 8054.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805402'))),
#  'Census Tract 8055.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805501'))),
#  'Census Tract 8055.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805502'))),
#  'Census Tract 8056, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805600'))),
#  'Census Tract 8057.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805701'))),
#  'Census Tract 8057.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805702'))),
#  'Census Tract 8058.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805801'))),
#  'Census Tract 8058.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805802'))),
#  'Census Tract 8059.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805901'))),
#  'Census Tract 8059.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '805902'))),
#  'Census Tract 8060.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806001'))),
#  'Census Tract 8060.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806002'))),
#  'Census Tract 8060.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806003'))),
#  'Census Tract 8060.04, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806004'))),
#  'Census Tract 8061.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806102'))),
#  'Census Tract 8061.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806103'))),
#  'Census Tract 8061.04, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806104'))),
#  'Census Tract 8062.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806201'))),
#  'Census Tract 8062.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806202'))),
#  'Census Tract 8063, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806300'))),
#  'Census Tract 8064, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806400'))),
#  'Census Tract 8065.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806501'))),
#  'Census Tract 8065.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806502'))),
#  'Census Tract 8066, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806600'))),
#  'Census Tract 8067, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806700'))),
#  'Census Tract 8068.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806801'))),
#  'Census Tract 8071, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '807100'))),
#  'Census Tract 8068.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806802'))),
#  'Census Tract 8069, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '806900'))),
#  'Census Tract 8070, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '807000'))),
#  'Census Tract 705, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '070500'))),
#  'Census Tract 706, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '070600'))),
#  'Census Tract 707, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '070700'))),
#  'Census Tract 710, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '071000'))),
#  'Census Tract 711, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '071100'))),
#  'Census Tract 712, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '071200'))),
#  'Census Tract 713, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '071300'))),
#  'Census Tract 714, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '071400'))),
#  'Census Tract 715, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '071500'))),
#  'Census Tract 716, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '071600'))),
#  'Census Tract 717, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '071700'))),
#  'Census Tract 718, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '071800'))),
#  'Census Tract 801, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '080100'))),
#  'Census Tract 802.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '080201'))),
#  'Census Tract 802.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '080202'))),
#  'Census Tract 803, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '080300'))),
#  'Census Tract 804, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '080400'))),
#  'Census Tract 810, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '081000'))),
#  'Census Tract 811, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '081100'))),
#  'Census Tract 812.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '081201'))),
#  'Census Tract 812.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '081202'))),
#  'Census Tract 813, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '081300'))),
#  'Census Tract 814.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '081401'))),
#  'Census Tract 814.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '081402'))),
#  'Census Tract 814.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '081403'))),
#  'Census Tract 815, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '081500'))),
#  'Census Tract 816, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '081600'))),
#  'Census Tract 817, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '081700'))),
#  'Census Tract 818, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '081800'))),
#  'Census Tract 819, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '081900'))),
#  'Census Tract 901, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '090100'))),
#  'Census Tract 902, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '090200'))),
#  'Census Tract 903, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '090300'))),
#  'Census Tract 1001, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '100100'))),
#  'Census Tract 1002, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '100200'))),
#  'Census Tract 1003, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '100300'))),
#  'Census Tract 1004, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '100400'))),
#  'Census Tract 1005, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '100500'))),
#  'Census Tract 1006, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '100600'))),
#  'Census Tract 1007, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '100700'))),
#  'Census Tract 1101, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '110100'))),
#  'Census Tract 1102, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '110200'))),
#  'Census Tract 1103, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '110300'))),
#  'Census Tract 1104, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '110400'))),
#  'Census Tract 1105.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '110501'))),
#  'Census Tract 1105.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '110502'))),
#  'Census Tract 1201, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '120100'))),
#  'Census Tract 1202, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '120200'))),
#  'Census Tract 8359, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '835900'))),
#  'Census Tract 8360, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '836000'))),
#  'Census Tract 8361, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '836100'))),
#  'Census Tract 8362, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '836200'))),
#  'Census Tract 8363, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '836300'))),
#  'Census Tract 8364, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '836400'))),
#  'Census Tract 8365, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '836500'))),
#  'Census Tract 8366, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '836600'))),
#  'Census Tract 8367, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '836700'))),
#  'Census Tract 8368, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '836800'))),
#  'Census Tract 8369, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '836900'))),
#  'Census Tract 8370, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '837000'))),
#  'Census Tract 8371, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '837100'))),
#  'Census Tract 8373, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '837300'))),
#  'Census Tract 8374, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '837400'))),
#  'Census Tract 8378, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '837800'))),
#  'Census Tract 8380, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '838000'))),
#  'Census Tract 8381, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '838100'))),
#  'Census Tract 8382, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '838200'))),
# ...
#  'Census Tract 8285.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '828505'))),
#  'Census Tract 8285.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '828506'))),
#  'Census Tract 8286.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '828601'))),
#  'Census Tract 8286.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '828602'))),
#  'Census Tract 8287.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '828701'))),
#  'Census Tract 8287.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '828702'))),
#  'Census Tract 8288.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '828801'))),
#  'Census Tract 8288.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '828802'))),
#  'Census Tract 8289, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '828900'))),
#  'Census Tract 8290, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '829000'))),
#  'Census Tract 8291, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '829100'))),
#  'Census Tract 8292, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '829200'))),
#  'Census Tract 8293.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '829301'))),
#  'Census Tract 8293.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '829302'))),
#  'Census Tract 8294.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '829401'))),
#  'Census Tract 8294.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '829402'))),
#  'Census Tract 8295, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '829500'))),
#  'Census Tract 8296, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '829600'))),
#  'Census Tract 8297, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '829700'))),
#  'Census Tract 8298, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '829800'))),
#  'Census Tract 8299.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '829901'))),
#  'Census Tract 8299.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '829902'))),
#  'Census Tract 8300.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '830001'))),
#  'Census Tract 8300.03, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '830003'))),
#  'Census Tract 8300.04, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '830004'))),
#  'Census Tract 8300.05, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '830005'))),
#  'Census Tract 8300.06, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '830006'))),
#  'Census Tract 8300.07, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '830007'))),
#  'Census Tract 8300.08, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '830008'))),
#  'Census Tract 3514, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '351400'))),
#  'Census Tract 3515, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '351500'))),
#  'Census Tract 3602, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '360200'))),
#  'Census Tract 3801, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '380100'))),
#  'Census Tract 3802, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '380200'))),
#  'Census Tract 3805, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '380500'))),
#  'Census Tract 3807, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '380700'))),
#  'Census Tract 3812, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '381200'))),
#  'Census Tract 3814, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '381400'))),
#  'Census Tract 3815, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '381500'))),
#  'Census Tract 3817, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '381700'))),
#  'Census Tract 3818, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '381800'))),
#  'Census Tract 3819, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '381900'))),
#  'Census Tract 3901, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '390100'))),
#  'Census Tract 3902, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '390200'))),
#  'Census Tract 3903, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '390300'))),
#  'Census Tract 3904, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '390400'))),
#  'Census Tract 3905, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '390500'))),
#  'Census Tract 3906, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '390600'))),
#  'Census Tract 3907, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '390700'))),
#  'Census Tract 4003, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '400300'))),
#  'Census Tract 4004, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '400400'))),
#  'Census Tract 4005, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '400500'))),
#  'Census Tract 4008, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '400800'))),
#  'Census Tract 4101, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '410100'))),
#  'Census Tract 4102, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '410200'))),
#  'Census Tract 4105, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '410500'))),
#  'Census Tract 4106, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '410600'))),
#  'Census Tract 4107, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '410700'))),
#  'Census Tract 4108, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '410800'))),
#  'Census Tract 4109, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '410900'))),
#  'Census Tract 4110, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '411000'))),
#  'Census Tract 4111, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '411100'))),
#  'Census Tract 4112, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '411200'))),
#  'Census Tract 4201, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '420100'))),
#  'Census Tract 4202, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '420200'))),
#  'Census Tract 4203, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '420300'))),
#  'Census Tract 4204, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '420400'))),
#  'Census Tract 4205, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '420500'))),
#  'Census Tract 4206, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '420600'))),
#  'Census Tract 4207, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '420700'))),
#  'Census Tract 4208, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '420800'))),
#  'Census Tract 4212, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '421200'))),
#  'Census Tract 4301.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '430101'))),
#  'Census Tract 4301.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '430102'))),
#  'Census Tract 4302, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '430200'))),
#  'Census Tract 4303, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '430300'))),
#  'Census Tract 4304, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '430400'))),
#  'Census Tract 8072, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '807200'))),
#  'Census Tract 8073, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '807300'))),
#  'Census Tract 8074, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '807400'))),
#  'Census Tract 8075, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '807500'))),
#  'Census Tract 8076, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '807600'))),
#  'Census Tract 8077, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '807700'))),
#  'Census Tract 8078, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '807800'))),
#  'Census Tract 8079, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '807900'))),
#  'Census Tract 8080.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '808001'))),
#  'Census Tract 8080.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '808002'))),
#  'Census Tract 8081, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '808100'))),
#  'Census Tract 8082, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '808200'))),
#  'Census Tract 8083.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '808301'))),
#  'Census Tract 8083.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '808302'))),
#  'Census Tract 8084, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '808400'))),
#  'Census Tract 8085, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '808500'))),
#  'Census Tract 8086, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '808600'))),
#  'Census Tract 8087.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '808702'))),
#  'Census Tract 8088, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '808800'))),
#  'Census Tract 8089, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '808900'))),
#  'Census Tract 8090, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '809000'))),
#  'Census Tract 8091, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '809100'))),
#  'Census Tract 8092, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '809200'))),
#  'Census Tract 8093, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '809300'))),
#  'Census Tract 8094, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '809400'))),
#  'Census Tract 8095, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '809500'))),
#  'Census Tract 8096, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '809600'))),
#  'Census Tract 8097, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '809700'))),
#  'Census Tract 8098, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '809800'))),
#  'Census Tract 8099, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '809900'))),
#  'Census Tract 8100, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '810000'))),
#  'Census Tract 8101, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '810100'))),
#  'Census Tract 8102, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '810200'))),
#  'Census Tract 8103.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '810301'))),
#  'Census Tract 8103.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '810302'))),
#  'Census Tract 8104, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '810400'))),
#  'Census Tract 8105.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '810501'))),
#  'Census Tract 8105.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '810502'))),
#  'Census Tract 8106, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '810600'))),
#  'Census Tract 8107.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '810701'))),
#  'Census Tract 8107.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '810702'))),
#  'Census Tract 8108, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '810800'))),
#  'Census Tract 8109, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '810900'))),
#  'Census Tract 8110, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '811000'))),
#  'Census Tract 8111, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '811100'))),
#  'Census Tract 8112, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '811200'))),
#  'Census Tract 8113.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '811301'))),
#  'Census Tract 4305, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '430500'))),
#  'Census Tract 4306, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '430600'))),
#  'Census Tract 4307, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '430700'))),
#  'Census Tract 4308, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '430800'))),
#  'Census Tract 4309, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '430900'))),
#  'Census Tract 4312, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '431200'))),
#  'Census Tract 4313.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '431301'))),
#  'Census Tract 4313.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '431302'))),
#  'Census Tract 4314, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '431400'))),
#  'Census Tract 4401.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '440101'))),
#  'Census Tract 4401.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '440102'))),
#  'Census Tract 4402.01, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '440201'))),
#  'Census Tract 4402.02, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '440202'))),
#  'Census Tract 4403, Cook County, Illinois': censusgeo((('state', '17'), ('county', '031'), ('tract', '440300'))),
#  ...}

# %%
# download all us census tract info
